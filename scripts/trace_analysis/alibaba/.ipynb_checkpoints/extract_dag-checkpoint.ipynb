# %%
#!/usr/bin/python3
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import graph_tool as gt
from graph_tool.all import *
from matplotlib.ticker import MaxNLocator
import io
import string

output = io.StringIO()


class Del:
  def __init__(self, keep=string.digits):
    self.comp = dict((ord(c),c) for c in keep)
  def __getitem__(self, k):
    return self.comp.get(k)

DD = Del()


def dump_dag(job_graph):
    job_graph.save("/local0/graph.dot", 'dot')

def get_critical_path(task_graph):
    return "1_3_2_5"

def build_graph(subtasks):
    num_subtasks_in_job = len(subtasks)
    g = gt.Graph(directed=True)
    g.add_vertex(num_subtasks_in_job)
    count_independent_tasks = 0;

    # Build the graph
    vertex_index = 0;
    vertex_map = dict()
    for row in subtasks:
        vertex_label = [int(i.translate(DD)) -1 for i in row.split('_')][0]
        vertex_map.update({vertex_label: vertex_index})
        vertex_index = vertex_index + 1;
    
    for row in subtasks:
        dependencies = [int(i.translate(DD)) -1 for i in row.split('_')]
        
        if len(dependencies) == 1:
            count_independent_tasks = count_independent_tasks + 1
            continue;
        child_task = vertex_map[dependencies[0]]
        child_vertex = g.vertex(child_task)
        for parent_task in dependencies[1:]:
            if parent_task in vertex_map:
                parent_vertex = g.vertex(vertex_map[parent_task])
                g.add_edge(parent_vertex, child_vertex)
    
    print("\t\t# of independent tasks is " + str(count_independent_tasks) + 
          ", in degree: " + str(gt.stats.vertex_average(g, "in")) +
          ", out degree: " + str(gt.stats.vertex_average(g, "out")))        
    return g;

def get_subtask_stats(jobId):
    instance_statistics['run_time'] = instance_statistics['End Time'] - instance_statistics['Start Time']

    instance_statistics_gb_task = instance_statistics.groupby(['Task'])

    tasks_runtime = instance_statistics_gb_task['End Time'].max() - instance_statistics_gb_task['Start Time'].min()
    tasks_start_delay = instance_statistics_gb_task['Start Time'].max() - instance_statistics_gb_task['Start Time'].min()
    task_max_instance = instance_statistics_gb_task['run_time'].max()
    task_min_instance = instance_statistics_gb_task['run_time'].min()

    task_statistics2 = pd.DataFrame({'min instance time': task_min_instance,
                                     'max instance time': task_max_instance,
                                     'run time': tasks_runtime,
                                     'schedule delay': tasks_start_delay})
    return task_statistics2;

# %%
file_name = "/local0/batch_task.csv"

# Read Batch Data, hint: Job and Type column should swap
data = pd.read_csv(file_name, names=['Name', '# Instances', 'Job', 'Type', 'Status', 'Start Time', 'End Time', 'CPU', 'Mem'])
#total_number_of_jobs = len(data.groupby(['Job']))
#print("Total number of submitted batch jobs: " + str(total_number_of_jobs))
#total_number_of_tasks = data[['Name', 'Job']].nunique()
#print("Total number of submitted task: " + str(total_number_of_jobs))

# Filter jobs with dependency, dataset has two types of batch jobs, w/wo DAG info and 
data_dag = data.loc[~data['Name'].str.startswith('task_', na=False)]

print("Jobs with Dags .......")
# group jobs by their JobId
job_groups_by_jobId = data_dag.groupby(['Job']);
print("# of jobs with Dags: " + str(len(job_groups_by_jobId)))

# Count DAGs by size
freq_number_tasks_per_dag = job_groups_by_jobId.size()
tasks_per_dag = freq_number_tasks_per_dag.to_frame().rename(columns={0: "DAG size"})
tasks_per_dag.reset_index(inplace=True)
tasks_per_dag['run_time'] = 0
tasks_per_dag['critical_path'] = 0
# Out:
# Jobs with Dags .......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0395a612083e> in <module>
#      14 # group jobs by their JobId
#      15 job_groups_by_jobId = data_dag.groupby(['Job']);
# ---> 16 print("# of jobs with Dags: " + str(len(job_groups_by_jobId)))
#      17
#      18 # Count DAGs by size
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __len__(self)
#     369
#     370     def __len__(self):
# --> 371         return len(self.groups)
#     372
#     373     def __unicode__(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in groups(self)
#     388         """
#     389         self._assure_grouper()
# --> 390         return self.grouper.groups
#     391
#     392     @property
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/ops.py in groups(self)
#     237         """ dict {group name -> group labels} """
#     238         if len(self.groupings) == 1:
# --> 239             return self.groupings[0].groups
#     240         else:
#     241             to_groupby = lzip(*(ping.grouper for ping in self.groupings))
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/grouper.py in groups(self)
#     398     def groups(self):
#     399         return self.index.groupby(Categorical.from_codes(self.labels,
# --> 400                                                          self.group_index))
#     401
#     402
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in groupby(self, values)
#    4435
#    4436         # map to the label
# -> 4437         result = {k: self.take(v) for k, v in compat.iteritems(result)}
#    4438
#    4439         return result
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in <dictcomp>(.0)
#    4435
#    4436         # map to the label
# -> 4437         result = {k: self.take(v) for k, v in compat.iteritems(result)}
#    4438
#    4439         return result
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     797                 raise ValueError(msg.format(self.__class__.__name__))
#     798             taken = self.values.take(indices)
# --> 799         return self._shallow_copy(taken)
#     800
#     801     def _assert_take_fillable(self, values, indices, allow_fill=True,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/numeric.py in _shallow_copy(self, values, **kwargs)
#      69         if values is not None and not self._can_hold_na:
#      70             # Ensure we are not returning an Int64Index with float data:
# ---> 71             return self._shallow_copy_with_infer(values=values, **kwargs)
#      72         return (super(NumericIndex, self)._shallow_copy(values=values,
#      73                                                         **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in _shallow_copy_with_infer(self, values, **kwargs)
#     605             except (TypeError, ValueError):
#     606                 pass
# --> 607         return Index(values, **attributes)
#     608
#     609     def _update_inplace(self, result, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     401
#     402             if is_signed_integer_dtype(data.dtype):
# --> 403                 from .numeric import Int64Index
#     404                 return Int64Index(data, copy=copy, dtype=dtype, name=name)
#     405             elif is_unsigned_integer_dtype(data.dtype):
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
dags_groupby_size = tasks_per_dag.groupby('DAG size')
for name, group in dags_groupby_size:
    dag_size = name
    print("DAG size:" + str(dag_size) + ", Number of Jobs with this size:" + str(len(group)))

    if dag_size == 1:
        '''
        print("Process runtime of Single Jobs")

        single_job_dags = pd.merge(data_dag, group, on='Job', how='inner')
        single_job_dags['Run Time'] = single_job_dags['End Time'] - joined['Start Time'] + 1
        single_job_dags = single_job_dags.loc[single_job_dags['Run Time'] > 0];
        print(len(single_job_dags))

        print("Mininum # of instances in single jobs: " + str(min(single_job_dags['# Instances'])))
        print("Maximum # of instances in single jobs: " + str(max(single_job_dags['# Instances'])))
        print("Mininum run time of single jobs: " +str(min(single_job_dags['Run Time'])))
        print("Maximum run time of single jobs: " + str(max(single_job_dags['Run Time'])))
        print("Average run time of single jobs:" + str(single_job_dags['Run Time'].mean()) )
        print("Standard deviation of single jobs run time:" + str(single_job_dags['Run Time'].std()) )
        print("Variance of single jobs run time:" + str(single_job_dags['Run Time'].var()) )
        '''
        continue;

        
    if dag_size == 2:
        continue;
        
        
    # groupby DAGs by jobId
    tasks_ofsize_dagsize = pd.merge(data_dag, group, on='Job', how='inner')
    jobs_ofsize_dagsize = tasks_ofsize_dagsize.groupby(['Job'])

    counter = 0;
    for name, group in jobs_ofsize_dagsize:
        jobId = name;
        job_statistics = data_dag.loc[data_dag['Job'] == jobId]
        job_runtime = max(job_statistics['End Time']) - min(job_statistics['Start Time'])
        print("\tProcess Job:" + jobId + ", of size " + str(dag_size) + ', runtime is: ' + str(job_runtime))

        #subtask_statistics = get_subtask_stats(jobId)

        job_statistics['Name'] = job_statistics['Name'].map(lambda x: x.lstrip('MJR'))
        subtasks = job_statistics['Name'].values
        subtask_graph = build_graph(subtasks)
        #dump_dag(subtask_graph)
        if counter == 1000:
            break;
        counter += 1
        #dags_groupby_size['critical_path'].loc[job_ofsize_dagsize['Job'] == jobId] = get_critical_path(subtask_graph)
    break;
# Out:
# DAG size:1, Number of Jobs with this size:1315457
# DAG size:2, Number of Jobs with this size:634561
# DAG size:3, Number of Jobs with this size:404402
# 	Process Job:j_1000012, of size 3, runtime is: 2364
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 	Process Job:j_100002, of size 3, runtime is: 320
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000034, of size 3, runtime is: 4
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000037, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000049, of size 3, runtime is: 13
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000075, of size 3, runtime is: 11
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000095, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_1000104, of size 3, runtime is: 19
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000108, of size 3, runtime is: 51
# 		# of independent tasks is 0, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000109, of size 3, runtime is: 25
# 		# of independent tasks is 0, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000132, of size 3, runtime is: 328
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000133, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000155, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000182, of size 3, runtime is: 10
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000197, of size 3, runtime is: 47
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000207, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000209, of size 3, runtime is: 607033
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000211, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000219, of size 3, runtime is: 173
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100022, of size 3, runtime is: 39
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000250, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000266, of size 3, runtime is: 122
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000279, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000287, of size 3, runtime is: 29
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000294, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000309, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000312, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000321, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000325, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000326, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000339, of size 3, runtime is: 9
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000343, of size 3, runtime is: 13
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000349, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000357, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100036, of size 3, runtime is: 173
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000364, of size 3, runtime is: 19
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100038, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000407, of size 3, runtime is: 80
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000423, of size 3, runtime is: 21
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000481, of size 3, runtime is: 26
# 		# of independent tasks is 2, in degree: (0.3333333333333333, 0.2721655269759087), out degree: (0.3333333333333333, 0.2721655269759087)
# 	Process Job:j_1000489, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100049, of size 3, runtime is: 111
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000492, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000494, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100051, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000543, of size 3, runtime is: 119
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000560, of size 3, runtime is: 4
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000569, of size 3, runtime is: 16
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000572, of size 3, runtime is: 25
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000582, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000583, of size 3, runtime is: 328
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000584, of size 3, runtime is: 148
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000585, of size 3, runtime is: 30
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000596, of size 3, runtime is: 42
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000606, of size 3, runtime is: 5
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000609, of size 3, runtime is: 2
# 		# of independent tasks is 2, in degree: (0.3333333333333333, 0.2721655269759087), out degree: (0.3333333333333333, 0.2721655269759087)
# 	Process Job:j_1000635, of size 3, runtime is: 31
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000640, of size 3, runtime is: 578
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100066, of size 3, runtime is: 11
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000675, of size 3, runtime is: 18
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000695, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000706, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.3333333333333333, 0.2721655269759087), out degree: (0.3333333333333333, 0.2721655269759087)
# 	Process Job:j_100072, of size 3, runtime is: 12
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000723, of size 3, runtime is: 61
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000727, of size 3, runtime is: 10
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000735, of size 3, runtime is: 40
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100074, of size 3, runtime is: 35
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000746, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000753, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000758, of size 3, runtime is: 191
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000761, of size 3, runtime is: 25
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100078, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000790, of size 3, runtime is: 26
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_10008, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000814, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000816, of size 3, runtime is: 3
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000820, of size 3, runtime is: 267
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000825, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100084, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000845, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000853, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000858, of size 3, runtime is: 5
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000878, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000885, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100090, of size 3, runtime is: 71
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000914, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000919, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100092, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000938, of size 3, runtime is: 15
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000945, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000954, of size 3, runtime is: 53
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000965, of size 3, runtime is: 57
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1000996, of size 3, runtime is: 57
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001021, of size 3, runtime is: 784
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001026, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100104, of size 3, runtime is: 197
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100106, of size 3, runtime is: 6
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001072, of size 3, runtime is: 82
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001078, of size 3, runtime is: 12
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001080, of size 3, runtime is: 23
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001129, of size 3, runtime is: 124
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001152, of size 3, runtime is: 19
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001156, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001161, of size 3, runtime is: 13
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001163, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001170, of size 3, runtime is: 0
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001193, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100121, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001226, of size 3, runtime is: 11
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001238, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.5443310539518174)
# 	Process Job:j_100125, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001251, of size 3, runtime is: 39
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001257, of size 3, runtime is: 22
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001267, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100131, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001329, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001340, of size 3, runtime is: 32
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001344, of size 3, runtime is: 59
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001355, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001359, of size 3, runtime is: 806
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001382, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001389, of size 3, runtime is: 131
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001402, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001417, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001420, of size 3, runtime is: 67
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001422, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001426, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001440, of size 3, runtime is: 4
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001468, of size 3, runtime is: 330
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001475, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001484, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001487, of size 3, runtime is: 284
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_1001489, of size 3, runtime is: 65
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001494, of size 3, runtime is: 38
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001496, of size 3, runtime is: 69
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001498, of size 3, runtime is: 3
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001504, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001513, of size 3, runtime is: 7
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001514, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001516, of size 3, runtime is: 42
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001523, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001537, of size 3, runtime is: 34
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100155, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001577, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100158, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001583, of size 3, runtime is: 37
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001617, of size 3, runtime is: 381
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001618, of size 3, runtime is: 32
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001656, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001658, of size 3, runtime is: 37
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100168, of size 3, runtime is: 16
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_1001680, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100170, of size 3, runtime is: 141
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001713, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001714, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001722, of size 3, runtime is: 576
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001727, of size 3, runtime is: 276
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001728, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.3333333333333333, 0.2721655269759087), out degree: (0.3333333333333333, 0.2721655269759087)
# 	Process Job:j_1001732, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001737, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100174, of size 3, runtime is: 22
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001751, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001768, of size 3, runtime is: 3
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001770, of size 3, runtime is: 337
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001776, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001791, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001792, of size 3, runtime is: 72
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001799, of size 3, runtime is: 18
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001803, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100181, of size 3, runtime is: 336
# 		# of independent tasks is 3, in degree: (0.0, 0.0), out degree: (0.0, 0.0)
# 	Process Job:j_1001823, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.5443310539518174)
# 	Process Job:j_1001824, of size 3, runtime is: 203
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001832, of size 3, runtime is: 22
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001851, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001857, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001864, of size 3, runtime is: 25
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001901, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001903, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001918, of size 3, runtime is: 42
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001937, of size 3, runtime is: 758
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001939, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001945, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001953, of size 3, runtime is: 502
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001958, of size 3, runtime is: 33
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001959, of size 3, runtime is: 105
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001961, of size 3, runtime is: 1024
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001963, of size 3, runtime is: 192
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100197, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001971, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001977, of size 3, runtime is: 21
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100198, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1001983, of size 3, runtime is: 14
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_10020, of size 3, runtime is: 159
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002002, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002005, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.5443310539518174)
# 	Process Job:j_1002013, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002016, of size 3, runtime is: 8
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002033, of size 3, runtime is: 4
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002036, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002037, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002047, of size 3, runtime is: 27
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002094, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002100, of size 3, runtime is: 6
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002118, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002157, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002159, of size 3, runtime is: 6
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002178, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002180, of size 3, runtime is: 133
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.5443310539518174)
# 	Process Job:j_1002208, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002213, of size 3, runtime is: 26
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002215, of size 3, runtime is: 35
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002216, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002222, of size 3, runtime is: 5
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002240, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002279, of size 3, runtime is: 55
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100228, of size 3, runtime is: 10
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002287, of size 3, runtime is: 58
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_10023, of size 3, runtime is: 167
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002303, of size 3, runtime is: 4
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002309, of size 3, runtime is: 372
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002316, of size 3, runtime is: 2
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002325, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100233, of size 3, runtime is: 39
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002335, of size 3, runtime is: 107
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002338, of size 3, runtime is: 0
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002342, of size 3, runtime is: 28
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002357, of size 3, runtime is: 563
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002381, of size 3, runtime is: 1
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002384, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002393, of size 3, runtime is: 1
# 		# of independent tasks is 3, in degree: (0.0, 0.0), out degree: (0.0, 0.0)
# 	Process Job:j_1002397, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002404, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002418, of size 3, runtime is: 43
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_1002437, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002443, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002445, of size 3, runtime is: 2
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002446, of size 3, runtime is: 175
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002449, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002463, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002468, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002469, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002476, of size 3, runtime is: 18
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002487, of size 3, runtime is: 42
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002507, of size 3, runtime is: 44
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002513, of size 3, runtime is: 256
# 		# of independent tasks is 1, in degree: (1.0, 0.4714045207910317), out degree: (1.0, 0.4714045207910317)
# 	Process Job:j_1002525, of size 3, runtime is: 4
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002535, of size 3, runtime is: 8
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002550, of size 3, runtime is: 346
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002558, of size 3, runtime is: 14
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002570, of size 3, runtime is: 7
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002583, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002591, of size 3, runtime is: 66
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002594, of size 3, runtime is: 148
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002597, of size 3, runtime is: 519
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002607, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100263, of size 3, runtime is: 325
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002630, of size 3, runtime is: 153
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002635, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002650, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002655, of size 3, runtime is: 4
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002660, of size 3, runtime is: 40
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002669, of size 3, runtime is: 8
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002670, of size 3, runtime is: 3
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002673, of size 3, runtime is: 27
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002680, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002684, of size 3, runtime is: 46
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002708, of size 3, runtime is: 6
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002723, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002756, of size 3, runtime is: 5
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002757, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002766, of size 3, runtime is: 35
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002769, of size 3, runtime is: 21
# 		# of independent tasks is 2, in degree: (0.6666666666666666, 0.5443310539518174), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002775, of size 3, runtime is: 41
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002824, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002829, of size 3, runtime is: 0
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002832, of size 3, runtime is: 2
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002845, of size 3, runtime is: 22
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002858, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002861, of size 3, runtime is: 47
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002863, of size 3, runtime is: 9
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_1002884, of size 3, runtime is: 31
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100289, of size 3, runtime is: 1
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.5443310539518174)
# 	Process Job:j_1002890, of size 3, runtime is: 25
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# 	Process Job:j_100291, of size 3, runtime is: 20
# 		# of independent tasks is 1, in degree: (0.6666666666666666, 0.2721655269759087), out degree: (0.6666666666666666, 0.2721655269759087)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-471de4145d34> in <module>
#      35     for name, group in jobs_ofsize_dagsize:
#      36         jobId = name;
# ---> 37         job_statistics = data_dag.loc[data_dag['Job'] == jobId]
#      38         job_runtime = max(job_statistics['End Time']) - min(job_statistics['Start Time'])
#      39         print("\tProcess Job:" + jobId + ", of size " + str(dag_size) + ', runtime is: ' + str(job_runtime))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# KeyboardInterrupt:

# %%
file_name = "/local0/j_3989171.csv"

# Read Batch Data, hint: Job and Type column should swap
instance_statistics_raw = pd.read_csv(file_name, names=['instance', 'Task', 'Job', 'Type', 'Status', 'Start Time', 'End Time', 
                                     'machine_id', 'seq_no', 'total_seq_no',
                                     'cpu_avg', 'cpu_max', 'mem_avg', 'mem_max'])
instance_statistics = instance_statistics_raw[instance_statistics_raw['Status'] == 'Terminated']
instance_statistics['Task'] = instance_statistics['Task'].map(lambda x: x.lstrip('MJR'))

# %%
from matplotlib.ticker import MaxNLocator


minimum_time = 0

def format_func(value, tick_number):
    return int(value - minimum_time)


instance_statistics['run_time'] = instance_statistics['End Time'] - instance_statistics['Start Time']

instance_statistics_gb_task = instance_statistics.groupby(['Task'])
print(len(instance_statistics_gb_task))

tasks_runtime = instance_statistics_gb_task['End Time'].max() - instance_statistics_gb_task['Start Time'].min()
tasks_start_delay = instance_statistics_gb_task['Start Time'].max() - instance_statistics_gb_task['Start Time'].min()
task_max_instance = instance_statistics_gb_task['run_time'].max()
task_min_instance = instance_statistics_gb_task['run_time'].min()

task_statistics = pd.DataFrame({'min instance time': task_min_instance, 
                    'max instance time': task_max_instance,
                    'run time': tasks_runtime,
                    'schedule delay': tasks_start_delay})

task_statistics2 = job_withsize_203[['Name', '# Instances']].rename(columns={'Name':'Task'}).set_index('Task')

task_statistics = task_statistics.join(task_statistics2)
minimum_time = min(instance_statistics_gb_task['Start Time'].min().values) - 1

fig, ax = plt.subplots()
plt.locator_params(axis='y', nbins=6)
ax.hlines(task_statistics.index, 
           instance_statistics_gb_task['Start Time'].min().values, 
          instance_statistics_gb_task['End Time'].max().values)
ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax.yaxis.set_major_locator(MaxNLocator(8))

#pyplot.locator_params(axis='x', nbins=10)

plt.tight_layout()
plt.savefig('job_schedule.pdf', format='pdf', dpi=200)
plt.savefig('job_schedule.png', format='png', dpi=200)
plt.show()

print("Minumum run time of a task in DAG:" + str(min(task_statistics['run time'])))
print("Maximum run time of a task in DAG:" + str(max(task_statistics['run time'])))

# %%
#single_jobs = data_dag.loc[data_dag['Job'] == single_jobs['Job']]
#print(single_jobs['Job'])
for name, group in dags_groupby_size: 
    print("DAG size:" + str(name) + ", Number of Jobs with this size:" + str(len(group)))
    
    
    
    if name == 203:
        print(group)
        job_withsize_203 = pd.merge(data_dag, group, on='Job', how='inner')
        print(len(job_withsize_203))
        job_withsize_203_runtime = max(job_withsize_203['End Time']) - min(job_withsize_203['Start Time'])
        print(job_withsize_203_runtime)
        
        num_tasks_in_job = len(job_withsize_203)
        
        g = gt.Graph(directed=True)
        g.add_vertex(num_tasks_in_job)
        
        job_withsize_203['Name'] = job_withsize_203['Name'].map(lambda x: x.lstrip('MJR'))
        tasks = job_withsize_203['Name']
        
        count_independent_tasks = 0;
        # Build the graph
        for index, row in job_withsize_203.iterrows():
            dependencies = [int(i) -1 for i in row['Name'].split('_')] 
            if len(dependencies) == 1:
                count_independent_tasks = count_independent_tasks + 1
                print(str(row['Name']) + " is an independent task, # of indepent tasks: " 
                      + str(count_independent_tasks))
                continue;
            child_task = dependencies[0]
            child_vertex = g.vertex(child_task)
            for parent_task in dependencies[1:]:
                parent_vertex = g.vertex(parent_task)
                g.add_edge(parent_vertex, child_vertex)
            
        #pos = gt.draw.fruchterman_reingold_layout(g, n_iter=1000)
        pos = gt.draw.arf_layout(g, max_iter=0)
        gt.draw.graph_draw(g,pos = pos, vertex_text=g.vertex_index, vertex_font_size=8,inline=True,
                           output_size=(1000, 1000), output="j_of_size_203_dep_graph.png")
        print("Draw a DAG")

# %%
#!/usr/bin/python3
import sys
import graph_tool as gt
from graph_tool.all import *

g = gt.Graph(directed=False)
num_vertices = 5
g.add_vertex(5)
edge_weights = g.new_edge_property('double')
g.edge_properties['weight'] = edge_weights
for i in range(0,num_vertices):
    for j in range(i+1,num_vertices):
        e = g.add_edge(i,j)
        edge_weights[e] = 15
        
g.list_properties()

# %%
# Out:
# weight         (edge)    (type: double)

# %%
import json
import re
import graph_tool as gt
from graph_tool.all import *

string = "#DAG:\n#--------------------------------------------------\n# Map Reduce Plan                                  \n#--------------------------------------------------\nMapReduce node: {scope-64\nMap Plan: {\nStore(hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734:org.apache.pig.impl.io.InterStorage) - scope-65\n{alpha: New For Each(false,false,false,false,false,false)[bag] - scope-60\n{{Project[bytearray][0] - scope-48\n{{Project[bytearray][1] - scope-50\n{{Project[bytearray][2] - scope-52\n{{Project[bytearray][3] - scope-54\n{{Project[bytearray][4] - scope-56\n{{Project[bytearray][5] - scope-58\n{{alpha: Load(/pigmix5/pigmix_users:PigStorage('\x01')) - scope-47}\n\nGlobal sort: {false}\n\n}\n\nMapReduce node: {scope-67\nMap Plan: {\na1: Local Rearrange[tuple]{chararray}(false) - scope-71\n{Constant(all) - scope-70\n{New For Each(false)[tuple] - scope-69\n{{Project[bytearray][0] - scope-68\n{{Load(hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734:org.apache.pig.impl.builtin.RandomSampleLoader('org.apache.pig.impl.io.InterStorage','100')) - scope-66}\n\nReduce Plan: {\nStore(hdfs://kariz-1:9000/tmp/temp121776661/tmp-19359954:org.apache.pig.impl.io.InterStorage) - scope-80\n{New For Each(false)[tuple] - scope-79\n{{POUserFunc(org.apache.pig.impl.builtin.FindQuantiles)[tuple] - scope-78\n{{{Project[tuple][*] - scope-77\n{{New For Each(false,false)[tuple] - scope-76\n{{{Constant(10) - scope-75\n{{{a1: POSort[bag]() - scope-62\n{{{{Project[bytearray][0] - scope-74\n{{{{Project[bag][1] - scope-73\n{{{Package(Packager)[tuple]{chararray} - scope-72}\n\nGlobal sort: {false}\n\n}\n\nMapReduce node: {scope-82\nMap Plan: {\na1: Local Rearrange[tuple]{bytearray}(false) - scope-83\n{Project[bytearray][0] - scope-61\n{Load(hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734:org.apache.pig.impl.io.InterStorage) - scope-81}\n\nReduce Plan: {\na1: Store(/pigmix5/pigmix_users_sorted:PigStorage('\x01')) - scope-63\n{New For Each(true)[tuple] - scope-86\n{{Project[bag][1] - scope-85\n{{Package(LitePackager)[tuple]{bytearray} - scope-84}\n\nGlobal sort: {true}\n\nQuantile file: {hdfs://kariz-1:9000/tmp/temp121776661/tmp-19359954}\n\n}\n\n"
ls = string.split("\n")

start_new_job = False

g = gt.Graph(directed=True)
input_dc = dict()
output_dc = dict()

for x in ls:
    if x.startswith("#"):
        continue;
    if x.startswith("MapReduce node:"):
        start_new_job = True
        v = g.add_vertex();
        print("Start new job")
    if x.find("Store") != -1:
        result = x.split('(')[1].split(')')[0]
        extra = result.split(":")[-1]
        outputs = result.replace(":" + extra, "")
        output_dc[outputs] = v;        
        print("\tStore: " + outputs)
    if x.find("Load") != -1:
        result = x.split('(')[1].split(')')[0]
        extra = result.split(":")[-1]
        inputs =  result.replace(":" + extra, "")
        input_dc[outputs] = v;
        print("\tLoad: " + inputs)
        
for key in input_dc:
    if key in output_dc:
        vi = output_dc[key]
        vo = input_dc[key]
        g.add_edge(vi, vo)
    

gt.draw.graph_draw(g,vertex_text=g.vertex_index, vertex_font_size=8,inline=True,
                           output_size=(200, 200), output="pigmix_generator_graph.png")

print("Graph done")
# Out:
# Start new job
# 	Store: hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734
# 	Load: /pigmix5/pigmix_users
# Start new job
# 	Load: hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734
# 	Store: hdfs://kariz-1:9000/tmp/temp121776661/tmp-19359954
# Start new job
# 	Load: hdfs://kariz-1:9000/tmp/temp121776661/tmp1968173734
# 	Store: /pigmix5/pigmix_users_sorted
# Graph done

# %%
#!/usr/bin/python3
import sys
import graph_tool as gt
from graph_tool.all import *

g = gt.Graph(directed=False)
num_vertices = 5
g.add_vertex(5)
edge_weights = g.new_edge_property('double')
g.edge_properties['weight'] = edge_weights
for i in range(0,num_vertices):
    for j in range(i+1,num_vertices):
        e = g.add_edge(i,j)
        edge_weights[e] = 15
        
g.list_properties()
